# %%
import os

# %%
files = [f for f in os.listdir(r"..\..\uploads")]

# %%
files
# Out:
# ['20251102_230616_data-06-00078-with-cover.pdf',
#  '20251102_231500_data-06-00078-with-cover.pdf',
#  '20251102_231521_image.png',
#  '20251102_231541_flow.docx',
#  '20251102_231602_Cross-Platform_Evaluation_of_Reasoning_Capabilities_in_Foundation_Models.pdf',
#  '20251102_231602_Delegated_Authorization_for_Agents_Constrained_to.pdf',
#  '20251102_231602_LLMS_PROCESS_LISTS_WITH_GENERAL_FILTER_HEADS.pdf',
#  '20251102_231602_The_Era_of_Agentic_Organization.pdf',
#  '20251102_231602_The_Oversight_Game_Learning_to_Cooperatively_Balance_an_AI.pdf',
#  '20251102_231602_Unveiling_Intrinsic_Text_Bias_in_Multimodal.pdf',
#  '20251103_230555_data-06-00078-with-cover.pdf']

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

# %%
embedding = HuggingFaceBgeEmbeddings(
    model_name="BAAI/bge-m3",
    model_kwargs={'device': 'cpu'},   # or 'cuda' if you have GPU
    encode_kwargs={'normalize_embeddings': True}
)
